# %% [markdown]
# <a href="https://colab.research.google.com/github/syedabasmah/masters_thesis/blob/main/conversion/pre_dataset_yelpNYC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **preprocessing**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/drive/MyDrive/yelpNYC/metadataNYC",sep="\t",header=None)

# %%
df2 = pd.read_csv("/content/drive/MyDrive/yelpNYC/reviewContentNYC",sep="\t",header=None)

# %%
df1.head()
# Out:
#      0  1    2  3           4
# 0  923  0  3.0 -1  2014-12-08
# 1  924  0  3.0 -1  2013-05-16
# 2  925  0  4.0 -1  2013-07-01
# 3  926  0  4.0 -1  2011-07-28
# 4  927  0  4.0 -1  2010-11-01

# %%
df1.columns = ["user_id", "prod_id", "rating", "label", "date"]

# %%
df1.head()
# Out:
#    user_id  prod_id  rating  label        date
# 0      923        0     3.0     -1  2014-12-08
# 1      924        0     3.0     -1  2013-05-16
# 2      925        0     4.0     -1  2013-07-01
# 3      926        0     4.0     -1  2011-07-28
# 4      927        0     4.0     -1  2010-11-01

# %%
df1.shape
# Out:
# (359052, 5)

# %%
df2.columns = ["user_id", "prod_id", "date", "review"]

# %%
df2.head()
# Out:
#    user_id  prod_id        date  \
# 0      923        0  2014-12-08
# 1      924        0  2013-05-16
# 2      925        0  2013-07-01
# 3      926        0  2011-07-28
# 4      927        0  2010-11-01
#
#                                               review
# 0  The food at snack is a selection of popular Gr...
# 1  This little place in Soho is wonderful. I had ...
# 2  ordered lunch for 15 from Snack last Friday.  ...
# 3  This is a beautiful quaint little restaurant o...
# 4  Snack is great place for a  casual sit down lu...

# %%
df2.shape
# Out:
# (358957, 4)

# %%
pd.merge(df1,df2,on=['user_id','prod_id','date'],how='left')
# Out:
#         user_id  prod_id  rating  label        date  \
# 0           923        0     3.0     -1  2014-12-08
# 1           924        0     3.0     -1  2013-05-16
# 2           925        0     4.0     -1  2013-07-01
# 3           926        0     4.0     -1  2011-07-28
# 4           927        0     4.0     -1  2010-11-01
# ...         ...      ...     ...    ...         ...
# 359047   161146      349     5.0      1  2014-02-06
# 359048   116424      349     5.0      1  2014-01-31
# 359049   161147      349     5.0      1  2014-01-30
# 359050    97930      349     5.0      1  2014-01-25
# 359051     5260      349     5.0      1  2014-01-25
#
#                                                    review
# 0       The food at snack is a selection of popular Gr...
# 1       This little place in Soho is wonderful. I had ...
# 2       ordered lunch for 15 from Snack last Friday.  ...
# 3       This is a beautiful quaint little restaurant o...
# ...

# %%
dataset= pd.merge(df1,df2,on=['user_id','prod_id','date'],how='left')

# %%
dataset.head()
# Out:
#    user_id  prod_id  rating  label        date  \
# 0      923        0     3.0     -1  2014-12-08
# 1      924        0     3.0     -1  2013-05-16
# 2      925        0     4.0     -1  2013-07-01
# 3      926        0     4.0     -1  2011-07-28
# 4      927        0     4.0     -1  2010-11-01
#
#                                               review
# 0  The food at snack is a selection of popular Gr...
# 1  This little place in Soho is wonderful. I had ...
# 2  ordered lunch for 15 from Snack last Friday.  ...
# 3  This is a beautiful quaint little restaurant o...
# 4  Snack is great place for a  casual sit down lu...

# %%
dataset.shape
# Out:
# (359052, 6)

# %%
dataset.to_csv("yelpNYC.csv")
